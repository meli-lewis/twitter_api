# %%
import json
import os
from TwitterAPI import TwitterAPI

# %%
api = TwitterAPI(consumer_key=os.getenv(key='TW_KEY'),
                 consumer_secret=os.getenv(key='TW_SECRET'),
                 access_token_key=os.getenv(key='TW_TOKEN'),
                 access_token_secret=os.getenv(key='TW_TOKEN_SECRET'))

# %%
r = api.request('search/tweets', {'q':'cats',
                                  'lang':'en',
                                  'filter':'media'})

# %%
r.json()
# Out:
# {'search_metadata': {'completed_in': 0.044,
#   'count': 15,
#   'max_id': 893612280201400320,
#   'max_id_str': '893612280201400320',
#   'next_results': '?max_id=893612199997874175&q=cats%20filter%3Amedia&lang=en&include_entities=1',
#   'query': 'cats+filter%3Amedia',
#   'refresh_url': '?since_id=893612280201400320&q=cats%20filter%3Amedia&lang=en&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Aug 04 23:19:04 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/M4g8pPd3s1',
#       'expanded_url': 'https://twitter.com/AMAZlNGNATURE/status/892962579206877186/video/1',
#       'id': 892962195474046976,
#       'id_str': '892962195474046976',
#       'indices': [103, 126],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/892962195474046976/pu/img/AQWraLtpztF8XnL4.jpg',
# ...
